# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
model = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])# Your Code Here#
model.compile(optimizer="sgd", loss= 'mean_squared_error')
    
ys = np.array([10.0, 15.0, 30.0, 20.0, 25.0, 55.0, 105.0, 45.0], dtype=float)# Your Code Here#
xs = np.array([1.0,      2.0,       5.0,      3.0,      4.0,       10.0,    20.0,     8.0], dtype=float) # Your Code Here#
model.fit(xs, ys, epochs=1000)
print(model.predict([7.0]))
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 0s 7ms/sample - loss: 2867.3433
# Epoch 2/1000
# 8/8 [==============================] - 0s 203us/sample - loss: 901.5214
# Epoch 3/1000
# 8/8 [==============================] - 0s 228us/sample - loss: 287.3416
# Epoch 4/1000
# 8/8 [==============================] - 0s 303us/sample - loss: 95.3870
# Epoch 5/1000
# 8/8 [==============================] - 0s 268us/sample - loss: 35.3282
# Epoch 6/1000
# 8/8 [==============================] - 0s 260us/sample - loss: 16.4725
# Epoch 7/1000
# 8/8 [==============================] - 0s 244us/sample - loss: 10.4894
# Epoch 8/1000
# 8/8 [==============================] - 0s 297us/sample - loss: 8.5290
# Epoch 9/1000
# 8/8 [==============================] - 0s 314us/sample - loss: 7.8267
# Epoch 10/1000
# 8/8 [==============================] - 0s 280us/sample - loss: 7.5190
# Epoch 11/1000
# 8/8 [==============================] - 0s 286us/sample - loss: 7.3361
# Epoch 12/1000
# ...
